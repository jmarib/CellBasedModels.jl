# %%
using Pkg
Pkg.activate("C:/Users/ibzja/Documents/UPF_2022_2026/4t/2n_trimestre/Practiques_tutelades/CellBasedModels.jl")
# Out:
#   Activating project at `C:\Users\ibzja\Documents\UPF_2022_2026\4t\2n_trimestre\Practiques_tutelades\CellBasedModels.jl`
# ┌ Warning: The active manifest file has dependencies that were resolved with a different julia version (1.11.6). Unexpected behavior may occur.
# └ @ nothing C:\Users\ibzja\Documents\UPF_2022_2026\4t\2n_trimestre\Practiques_tutelades\CellBasedModels.jl\Manifest.toml:0
# ┌ Warning: The project dependencies or compat requirements have changed since the manifest was last resolved.
# │ It is recommended to `Pkg.resolve()` or consider `Pkg.update()` if necessary.
# └ @ Pkg.API C:\Users\ibzja\.julia\juliaup\julia-1.10.2+0.x64.w64.mingw32\share\julia\stdlib\v1.10\Pkg\src\API.jl:1807
#    Installed JpegTurbo_jll ─────────────────────── v3.1.4+0
#    Installed libfdk_aac_jll ────────────────────── v2.0.4+0
#    Installed OrdinaryDiffEqRKN ─────────────────── v1.8.0
#    Installed Libmount_jll ──────────────────────── v2.41.2+0
#    Installed x265_jll ──────────────────────────── v4.1.0+0
#    Installed DifferentialEquations ─────────────── v7.17.0
#    Installed MutableArithmetics ────────────────── v1.6.7
#    Installed OrdinaryDiffEqRosenbrock ──────────── v1.21.0
#    Installed SciMLPublic ───────────────────────── v1.0.1
#    Installed StatsFuns ─────────────────────────── v1.5.2
#    Installed OrdinaryDiffEqStabilizedRK ────────── v1.7.0
#    Installed Accessors ─────────────────────────── v0.1.43
#    Installed Preferences ───────────────────────── v1.5.1
#    Installed LERC_jll ──────────────────────────── v4.0.1+0
#    Installed LoggingExtras ─────────────────────── v1.2.0
#    Installed SciMLLogging ──────────────────────── v1.8.0
#    Installed Opus_jll ──────────────────────────── v1.6.0+0
#    Installed AlmostBlockDiagonals ──────────────── v0.1.10
#    Installed FastGaussQuadrature ───────────────── v1.1.0
#    Installed NonlinearSolve ────────────────────── v4.13.0
#    Installed BoundaryValueDiffEqFIRK ───────────── v1.9.0
#    Installed DomainSets ────────────────────────── v0.7.16
#    Installed PDMats ────────────────────────────── v0.11.37
#    Installed OrdinaryDiffEqSDIRK ───────────────── v1.10.0
#    Installed InlineStrings ─────────────────────── v1.4.5
#    Installed SciMLJacobianOperators ────────────── v0.1.12
#    Installed TimerOutputs ──────────────────────── v0.5.29
#    Installed StaticArrays ──────────────────────── v1.9.16
#    Installed ProgressMeter ─────────────────────── v1.11.0
#    Installed Bijections ────────────────────────── v0.2.2
#    Installed Polyester ─────────────────────────── v0.7.18
#    Installed OrdinaryDiffEqPRK ─────────────────── v1.7.0
#    Installed BoundaryValueDiffEqMIRK ───────────── v1.9.0
#    Installed Sundials_jll ──────────────────────── v7.5.0+0
#    Installed MaybeInplace ──────────────────────── v0.1.4
#    Installed RecursiveArrayTools ───────────────── v3.42.1
#    Installed ProtoBuf ──────────────────────────── v1.2.0
#    Installed OrdinaryDiffEqCore ────────────────── v2.3.0
#    Installed FileIO ────────────────────────────── v1.17.1
#    Installed ReTestItems ───────────────────────── v1.35.0
#    Installed OpenBLAS32_jll ────────────────────── v0.3.29+0
#    Installed RandomNumbers ─────────────────────── v1.6.0
#    Installed IntelOpenMP_jll ───────────────────── v2025.2.0+0
#    Installed OrdinaryDiffEqAdamsBashforthMoulton ─ v1.8.0
#    Installed Fontconfig_jll ────────────────────── v2.17.1+0
#    Installed OrdinaryDiffEqSSPRK ───────────────── v1.10.0
#    Installed Static ────────────────────────────── v1.3.1
#    Installed DataFrames ────────────────────────── v1.8.1
#    Installed TestEnv ───────────────────────────── v1.103.0
#    Installed Graphviz_jll ──────────────────────── v2.50.0+1
#    Installed WeakCacheSets ─────────────────────── v0.1.0
#    Installed OrdinaryDiffEqVerner ──────────────── v1.9.0
#    Installed FiniteDiff ────────────────────────── v2.29.0
#    Installed SteadyStateDiffEq ─────────────────── v2.8.0
#    Installed BoundaryValueDiffEq ───────────────── v5.18.0
#    Installed IrrationalConstants ───────────────── v0.2.6
#    Installed BoundaryValueDiffEqCore ───────────── v1.11.1
#    Installed FastPower ─────────────────────────── v1.3.0
#    Installed JLD2 ──────────────────────────────── v0.4.55
#    Installed DiffEqBase ────────────────────────── v6.194.0
#    Installed MultivariatePolynomials ───────────── v0.5.13
#    Installed BandedMatrices ────────────────────── v1.11.0
#    Installed SciMLBase ─────────────────────────── v2.131.0
#    Installed Pango_jll ─────────────────────────── v1.57.0+0
#    Installed CompositeTypes ────────────────────── v0.1.4
#    Installed OrdinaryDiffEqFIRK ────────────────── v1.19.0
#    Installed NonlinearSolveQuasiNewton ─────────── v1.12.0
#    Installed ADTypes ───────────────────────────── v1.21.0
#    Installed OrdinaryDiffEqNonlinearSolve ──────── v1.18.0
#    Installed SpecialFunctions ──────────────────── v2.6.1
#    Installed BoundaryValueDiffEqMIRKN ──────────── v1.8.0
#    Installed BenchmarkTools ────────────────────── v1.6.3
#    Installed SentinelArrays ────────────────────── v1.4.9
#    Installed Symbolics ─────────────────────────── v7.4.1
#    Installed BracketingNonlinearSolve ──────────── v1.6.2
#    Installed XZ_jll ────────────────────────────── v5.8.2+0
#    Installed LineSearch ────────────────────────── v0.1.5
#    Installed SimpleNonlinearSolve ──────────────── v2.10.0
#    Installed NonlinearSolveSpectralMethods ─────── v1.6.0
#    Installed DiffEqNoiseProcess ────────────────── v5.24.1
#    Installed LinearSolve ───────────────────────── v3.55.0
#    Installed StaticArraysCore ──────────────────── v1.4.4
#    Installed SparseConnectivityTracer ──────────── v1.1.3
#    Installed SparseMatrixColorings ─────────────── v0.4.23
#    Installed Random123 ─────────────────────────── v1.7.1
#    Installed JumpProcesses ─────────────────────── v9.19.3
#    Installed NLSolversBase ─────────────────────── v7.10.0
#    Installed LazyArrays ────────────────────────── v2.9.4
#    Installed x264_jll ──────────────────────────── v10164.0.1+0
#    Installed FreeType2_jll ─────────────────────── v2.13.4+0
#    Installed DataStructures ────────────────────── v0.19.3
#    Installed LeftChildRightSiblingTrees ────────── v0.2.1
#    Installed BufferedStreams ───────────────────── v1.2.2
#    Installed StatsAPI ──────────────────────────── v1.8.0
#    Installed Graphs ────────────────────────────── v1.13.3
#    Installed Compat ────────────────────────────── v4.18.1
#    Installed FastAlmostBandedMatrices ──────────── v0.1.5
#    Installed OrdinaryDiffEq ────────────────────── v6.105.0
#    Installed libpng_jll ────────────────────────── v1.6.53+0
#    Installed StatsBase ─────────────────────────── v0.34.9
#    Installed libaom_jll ────────────────────────── v3.13.1+0
#    Installed ArrayLayouts ──────────────────────── v1.12.2
#    Installed FlameGraphs ───────────────────────── v1.1.0
#    Installed OrdinaryDiffEqLinear ──────────────── v1.9.0
#    Installed DynamicPolynomials ────────────────── v0.6.4
#    Installed MatrixFactorizations ──────────────── v3.1.3
#    Installed SciMLStructures ───────────────────── v1.9.0
#    Installed GenericSchur ──────────────────────── v0.5.6
#    Installed oneTBB_jll ────────────────────────── v2022.0.0+1
#    Installed OrdinaryDiffEqExplicitRK ──────────── v1.7.0
#    Installed OrdinaryDiffEqPDIRK ───────────────── v1.9.0
#    Installed OrdinaryDiffEqQPRK ────────────────── v1.7.0
#    Installed Expat_jll ─────────────────────────── v2.7.3+0
#    Installed OrdinaryDiffEqFunctionMap ─────────── v1.8.0
#    Installed Sundials ──────────────────────────── v5.1.0
#    Installed StochasticDiffEq ──────────────────── v6.87.0
#    Installed SciMLOperators ────────────────────── v1.14.1
#    Installed PrettyTables ──────────────────────── v3.1.2
#    Installed OrdinaryDiffEqLowOrderRK ──────────── v1.9.0
#    Installed MKL_jll ───────────────────────────── v2025.2.0+0
#    Installed DiffEqCallbacks ───────────────────── v4.11.0
#    Installed Imath_jll ─────────────────────────── v3.2.2+0
#    Installed NonlinearSolveBase ────────────────── v2.9.0
#    Installed ExproniconLite ────────────────────── v0.10.14
#    Installed Libtiff_jll ───────────────────────── v4.7.2+0
#    Installed JLLWrappers ───────────────────────── v1.7.1
#    Installed EnzymeCore ────────────────────────── v0.8.17
#    Installed NonlinearSolveFirstOrder ──────────── v1.11.0
#    Installed BoundaryValueDiffEqShooting ───────── v1.9.0
#    Installed SymbolicLimits ────────────────────── v0.2.4
#    Installed Ogg_jll ───────────────────────────── v1.3.6+0
#    Installed OrdinaryDiffEqExponentialRK ───────── v1.11.0
#    Installed DelayDiffEq ───────────────────────── v5.64.0
#    Installed PProf ─────────────────────────────── v3.2.0
#    Installed ArrayInterface ────────────────────── v7.22.0
#    Installed ReadOnlyArrays ────────────────────── v0.2.0
#    Installed LineSearches ──────────────────────── v7.5.1
#    Installed OrdinaryDiffEqExtrapolation ───────── v1.12.0
#    Installed PreallocationTools ────────────────── v0.4.34
#    Installed SuiteSparse32_jll ─────────────────── v7.12.1+0
#    Installed IntervalArithmetic ────────────────── v1.0.2
#    Installed OrdinaryDiffEqTsit5 ───────────────── v1.8.0
#    Installed OrdinaryDiffEqLowStorageRK ────────── v1.10.0
#    Installed KernelAbstractions ────────────────── v0.9.39
#    Installed CommonSolve ───────────────────────── v0.2.6
#    Installed UnsafeAtomics ─────────────────────── v0.3.0
#    Installed OrdinaryDiffEqStabilizedIRK ───────── v1.9.0
#    Installed Libuuid_jll ───────────────────────── v2.41.2+0
#    Installed SimpleTraits ──────────────────────── v0.9.5
#    Installed pprof_jll ─────────────────────────── v2.0.0+0
#    Installed AbstractPlutoDingetjes ────────────── v1.3.2
#    Installed OpenEXR_jll ───────────────────────── v3.4.4+0
#    Installed Atomix ────────────────────────────── v1.1.2
#    Installed Krylov ────────────────────────────── v0.10.3
#    Installed DifferentiationInterface ──────────── v0.7.13
#    Installed ExponentialUtilities ──────────────── v1.29.0
#    Installed TaskLocalValues ───────────────────── v0.1.3
#    Installed Adapt ─────────────────────────────── v4.4.0
#    Installed OrdinaryDiffEqBDF ─────────────────── v1.13.0
#    Installed StrideArraysCore ──────────────────── v0.5.8
#    Installed libass_jll ────────────────────────── v0.17.4+0
#    Installed Rmath ─────────────────────────────── v0.9.0
#    Installed OpenSSL_jll ───────────────────────── v3.5.4+0
#    Installed Jieko ─────────────────────────────── v0.2.1
#    Installed RuntimeGeneratedFunctions ─────────── v0.5.16
#    Installed OrdinaryDiffEqDifferentiation ─────── v1.21.0
#    Installed IntegerMathUtils ──────────────────── v0.1.3
#    Installed FFMPEG_jll ────────────────────────── v8.0.1+0
#    Installed CPUSummary ────────────────────────── v0.2.7
#    Installed OrdinaryDiffEqFeagin ──────────────── v1.7.0
#    Installed CairoMakie ────────────────────────── v0.15.8
#    Installed TermInterface ─────────────────────── v2.0.0
#    Installed SymbolicUtils ─────────────────────── v4.10.0
#    Installed LAME_jll ──────────────────────────── v3.100.3+0
#    Installed OrdinaryDiffEqHighOrderRK ─────────── v1.8.0
#    Installed GettextRuntime_jll ────────────────── v0.22.4+0
#    Installed Optim ─────────────────────────────── v1.13.3
#    Installed StructArrays ──────────────────────── v0.7.2
#    Installed PoissonRandom ─────────────────────── v0.4.7
#    Installed BoundaryValueDiffEqAscher ─────────── v1.8.0
#    Installed libvorbis_jll ─────────────────────── v1.3.8+0
#    Installed Glib_jll ──────────────────────────── v2.86.2+0
#    Installed Moshi ─────────────────────────────── v0.3.7
#    Installed ResettableStacks ──────────────────── v1.2.0
#    Installed FillArrays ────────────────────────── v1.15.0
#    Installed SymbolicIndexingInterface ─────────── v0.3.46
#    Installed ForwardDiff ───────────────────────── v1.3.1
#    Installed OrdinaryDiffEqSymplecticRK ────────── v1.10.0
#    Installed OrdinaryDiffEqDefault ─────────────── v1.11.0
#    Installed OrdinaryDiffEqNordsieck ───────────── v1.7.0
#    Installed OrdinaryDiffEqIMEXMultistep ───────── v1.10.0
#    Installed FastBroadcast ─────────────────────── v0.3.5
#    Installed StringManipulation ────────────────── v0.4.2
#    Installed SortingAlgorithms ─────────────────── v1.2.2
#    Installed libwebp_jll ───────────────────────── v1.6.0+0
#    Installed Distributions ─────────────────────── v0.25.123
#    Installed StructUtils ───────────────────────── v2.6.0
# Precompiling project...
# failed to find source of parent package: "Statistics"
#
#
#
# Stacktrace:
#
#   [1] error(s::String)
#
#     @ Base .\error.jl:35
#
#   [2] explicit_manifest_uuid_path(project_file::String, pkg::Base.PkgId)
#
#     @ Base .\loading.jl:919
#
#   [3] manifest_uuid_path(env::String, pkg::Base.PkgId)
#
#     @ Base .\loading.jl:664
#
#   [4] locate_package_env(pkg::Base.PkgId, stopenv::Nothing)
#
#     @ Base .\loading.jl:423
#
#   [5] locate_package(pkg::Base.PkgId, stopenv::Nothing)
#
#     @ Base .\loading.jl:467
#
#   [6] locate_package
#
#     @ .\loading.jl:467 [inlined]
#
#   [7] precompile(ctx::Pkg.Types.Context, pkgs::Vector{Pkg.Types.PackageSpec}; internal_call::Bool, strict::Bool, warn_loaded::Bool, already_instantiated::Bool, timing::Bool, _from_loading::Bool, kwargs::@Kwargs{})
#
#     @ Pkg.API C:\Users\ibzja\.julia\juliaup\julia-1.10.2+0.x64.w64.mingw32\share\julia\stdlib\v1.10\Pkg\src\API.jl:1455
#
#   [8] _auto_precompile(ctx::Pkg.Types.Context, pkgs::Vector{Pkg.Types.PackageSpec}; warn_loaded::Bool, already_instantiated::Bool)
#
#     @ Pkg C:\Users\ibzja\.julia\juliaup\julia-1.10.2+0.x64.w64.mingw32\share\julia\stdlib\v1.10\Pkg\src\Pkg.jl:805
#
#   [9] instantiate(ctx::Pkg.Types.Context; manifest::Nothing, update_registry::Bool, verbose::Bool, platform::Base.BinaryPlatforms.Platform, allow_build::Bool, allow_autoprecomp::Bool, kwargs::@Kwargs{})
#
#     @ Pkg.API C:\Users\ibzja\.julia\juliaup\julia-1.10.2+0.x64.w64.mingw32\share\julia\stdlib\v1.10\Pkg\src\API.jl:1877
#
#  [10] instantiate
#
#     @ C:\Users\ibzja\.julia\juliaup\julia-1.10.2+0.x64.w64.mingw32\share\julia\stdlib\v1.10\Pkg\src\API.jl:1773 [inlined]
#
#  [11] instantiate()
#
#     @ Pkg.API C:\Users\ibzja\.julia\juliaup\julia-1.10.2+0.x64.w64.mingw32\share\julia\stdlib\v1.10\Pkg\src\API.jl:1772
#
#  [12] top-level scope
#
#     @ c:\Users\ibzja\Documents\UPF_2022_2026\4t\2n_trimestre\Practiques_tutelades\CellBasedModels.jl\examples\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W0sZmlsZQ==.jl:3

# %%
using GLMakie
using Distributions
using CellBasedModels
using GeometryBasics
# Out:
#   ✓ Atomix
#   ✓ CompositionsBase → CompositionsBaseInverseFunctionsExt
#   ✓ InverseFunctions → InverseFunctionsTestExt
#   ✓ MutableArithmetics
# ERROR: LoadError: ArgumentError: Package Statistics [10745b16-79ce-11e8-11f9-7d13ad32a3b2] is required but does not seem to be installed:
#  - Run `Pkg.instantiate()` to install all recorded dependencies.
#
# Stacktrace:
#   [1] _require(pkg::Base.PkgId, env::String)
#     @ Base .\loading.jl:1926
#   [2] __require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base .\loading.jl:1812
#   [3] #invoke_in_world#3
#     @ .\essentials.jl:926 [inlined]
#   [4] invoke_in_world
#     @ .\essentials.jl:923 [inlined]
#   [5] _require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base .\loading.jl:1803
#   [6] macro expansion
#     @ .\loading.jl:1790 [inlined]
#   [7] macro expansion
#     @ .\lock.jl:267 [inlined]
#   [8] __require(into::Module, mod::Symbol)
#     @ Base .\loading.jl:1753
#   [9] #invoke_in_world#3
#     @ .\essentials.jl:926 [inlined]
#  [10] invoke_in_world
#     @ .\essentials.jl:923 [inlined]
#  [11] require(into::Module, mod::Symbol)
#     @ Base .\loading.jl:1746
#  [12] include
#     @ .\Base.jl:495 [inlined]
#  [13] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::String)
#     @ Base .\loading.jl:2222
#  [14] top-level scope
#     @ stdin:3
# in expression starting at C:\Users\ibzja\.julia\packages\FixedPointNumbers\Dn4hv\src\FixedPointNumbers.jl:1
# in expression starting at stdin:3
# ERROR: LoadError: Failed to precompile FixedPointNumbers [53c48c17-4a7d-5ca2-90c5-79b7896eea93] to "C:\\Users\\ibzja\\.julia\\compiled\\v1.10\\FixedPointNumbers\\jl_9E64.tmp".
# Stacktrace:
#   [1] error(s::String)
#     @ Base .\error.jl:35
#   [2] compilecache(pkg::Base.PkgId, path::String, internal_stderr::IO, internal_stdout::IO, keep_loaded_modules::Bool)
#     @ Base .\loading.jl:2468
#   [3] compilecache
#     @ .\loading.jl:2340 [inlined]
#   [4] (::Base.var"#968#969"{Base.PkgId})()
#     @ Base .\loading.jl:1974
#   [5] mkpidlock(f::Base.var"#968#969"{Base.PkgId}, at::String, pid::Int32; kwopts::@Kwargs{stale_age::Int64, wait::Bool})
#     @ FileWatching.Pidfile C:\Users\ibzja\.julia\juliaup\julia-1.10.2+0.x64.w64.mingw32\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:93
#   [6] #mkpidlock#6
#     @ C:\Users\ibzja\.julia\juliaup\julia-1.10.2+0.x64.w64.mingw32\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:88 [inlined]
#   [7] trymkpidlock(::Function, ::Vararg{Any}; kwargs::@Kwargs{stale_age::Int64})
#     @ FileWatching.Pidfile C:\Users\ibzja\.julia\juliaup\julia-1.10.2+0.x64.w64.mingw32\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:111
#   [8] #invokelatest#2
#     @ .\essentials.jl:894 [inlined]
#   [9] invokelatest
#     @ .\essentials.jl:889 [inlined]
#  [10] maybe_cachefile_lock(f::Base.var"#968#969"{Base.PkgId}, pkg::Base.PkgId, srcpath::String; stale_age::Int64)
#     @ Base .\loading.jl:2983
#  [11] maybe_cachefile_lock
#     @ .\loading.jl:2980 [inlined]
#  [12] _require(pkg::Base.PkgId, env::String)
#     @ Base .\loading.jl:1970
#  [13] __require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base .\loading.jl:1812
#  [14] #invoke_in_world#3
#     @ .\essentials.jl:926 [inlined]
#  [15] invoke_in_world
#     @ .\essentials.jl:923 [inlined]
#  [16] _require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base .\loading.jl:1803
#  [17] macro expansion
#     @ .\loading.jl:1790 [inlined]
#  [18] macro expansion
#     @ .\lock.jl:267 [inlined]
#  [19] __require(into::Module, mod::Symbol)
#     @ Base .\loading.jl:1753
#  [20] #invoke_in_world#3
#     @ .\essentials.jl:926 [inlined]
#  [21] invoke_in_world
#     @ .\essentials.jl:923 [inlined]
#  [22] require(into::Module, mod::Symbol)
#     @ Base .\loading.jl:1746
#  [23] include
#     @ .\Base.jl:495 [inlined]
#  [24] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::String)
#     @ Base .\loading.jl:2222
#  [25] top-level scope
#     @ stdin:3
# in expression starting at C:\Users\ibzja\.julia\packages\GLMakie\1dQSN\src\GLMakie.jl:1
# in expression starting at stdin:3
# Failed to precompile GLMakie [e9467ef8-e4e7-5192-8a1a-b1aee30e663a] to "C:\\Users\\ibzja\\.julia\\compiled\\v1.10\\GLMakie\\jl_99DD.tmp".
#
#
#
# Stacktrace:
#
#   [1] error(s::String)
#
#     @ Base .\error.jl:35
#
#   [2] compilecache(pkg::Base.PkgId, path::String, internal_stderr::IO, internal_stdout::IO, keep_loaded_modules::Bool)
#
#     @ Base .\loading.jl:2468
#
#   [3] compilecache
#
#     @ .\loading.jl:2340 [inlined]
#
#   [4] (::Base.var"#968#969"{Base.PkgId})()
#
#     @ Base .\loading.jl:1974
#
#   [5] mkpidlock(f::Base.var"#968#969"{Base.PkgId}, at::String, pid::Int32; kwopts::@Kwargs{stale_age::Int64, wait::Bool})
#
#     @ FileWatching.Pidfile C:\Users\ibzja\.julia\juliaup\julia-1.10.2+0.x64.w64.mingw32\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:93
#
#   [6] #mkpidlock#6
#
#     @ C:\Users\ibzja\.julia\juliaup\julia-1.10.2+0.x64.w64.mingw32\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:88 [inlined]
#
#   [7] trymkpidlock(::Function, ::Vararg{Any}; kwargs::@Kwargs{stale_age::Int64})
#
#     @ FileWatching.Pidfile C:\Users\ibzja\.julia\juliaup\julia-1.10.2+0.x64.w64.mingw32\share\julia\stdlib\v1.10\FileWatching\src\pidfile.jl:111
#
#   [8] #invokelatest#2
#
#     @ .\essentials.jl:894 [inlined]
#
#   [9] invokelatest
#
#     @ .\essentials.jl:889 [inlined]
#
#  [10] maybe_cachefile_lock(f::Base.var"#968#969"{Base.PkgId}, pkg::Base.PkgId, srcpath::String; stale_age::Int64)
#
#     @ Base .\loading.jl:2983
#
#  [11] maybe_cachefile_lock
#
#     @ .\loading.jl:2980 [inlined]
#
#  [12] _require(pkg::Base.PkgId, env::String)
#
#     @ Base .\loading.jl:1970
#
#  [13] __require_prelocked(uuidkey::Base.PkgId, env::String)
#
#     @ Base .\loading.jl:1812
#
#  [14] #invoke_in_world#3
#
#     @ .\essentials.jl:926 [inlined]
#
#  [15] invoke_in_world
#
#     @ .\essentials.jl:923 [inlined]
#
#  [16] _require_prelocked(uuidkey::Base.PkgId, env::String)
#
#     @ Base .\loading.jl:1803
#
#  [17] macro expansion
#
#     @ .\loading.jl:1790 [inlined]
#
#  [18] macro expansion
#
#     @ .\lock.jl:267 [inlined]
#
#  [19] __require(into::Module, mod::Symbol)
#
#     @ Base .\loading.jl:1753
#
#  [20] #invoke_in_world#3
#
#     @ .\essentials.jl:926 [inlined]
#
#  [21] invoke_in_world
#
#     @ .\essentials.jl:923 [inlined]
#
#  [22] require(into::Module, mod::Symbol)
#
#     @ Base .\loading.jl:1746
#
#  [23] eval
#
#     @ .\boot.jl:385 [inlined]
#
#  [24] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#
#     @ Base .\loading.jl:2076
#
#  [25] #invokelatest#2
#
#     @ .\essentials.jl:892 [inlined]
#
#  [26] invokelatest
#
#     @ .\essentials.jl:889 [inlined]
#
#  [27] (::VSCodeServer.var"#220#221"{VSCodeServer.NotebookRunCellArguments, String})()
#
#     @ VSCodeServer c:\Users\ibzja\.vscode\extensions\julialang.language-julia-1.170.2\scripts\packages\VSCodeServer\src\serve_notebook.jl:24
#
#  [28] withpath(f::VSCodeServer.var"#220#221"{VSCodeServer.NotebookRunCellArguments, String}, path::String)
#
#     @ VSCodeServer c:\Users\ibzja\.vscode\extensions\julialang.language-julia-1.170.2\scripts\packages\VSCodeServer\src\repl.jl:278
#
#  [29] notebook_runcell_request(conn::VSCodeServer.JSONRPC.JSONRPCEndpoint{Base.PipeEndpoint, Base.PipeEndpoint, VSCodeServer.JSON.Serializations.StandardSerialization}, params::VSCodeServer.NotebookRunCellArguments, token::VSCodeServer.CancellationTokens.CancellationToken)
#
#     @ VSCodeServer c:\Users\ibzja\.vscode\extensions\julialang.language-julia-1.170.2\scripts\packages\VSCodeServer\src\serve_notebook.jl:13
#
#  [30] dispatch_msg(x::VSCodeServer.JSONRPC.JSONRPCEndpoint{Base.PipeEndpoint, Base.PipeEndpoint, VSCodeServer.JSON.Serializations.StandardSerialization}, dispatcher::VSCodeServer.JSONRPC.MsgDispatcher, msg::VSCodeServer.JSONRPC.Request)
#
#     @ VSCodeServer.JSONRPC c:\Users\ibzja\.vscode\extensions\julialang.language-julia-1.170.2\scripts\packages\JSONRPC\src\typed.jl:68
#
#  [31] serve_notebook(pipename::String, debugger_pipename::String, outputchannel_logger::Base.CoreLogging.SimpleLogger; error_handler::var"#9#14"{String})
#
#     @ VSCodeServer c:\Users\ibzja\.vscode\extensions\julialang.language-julia-1.170.2\scripts\packages\VSCodeServer\src\serve_notebook.jl:147
#
#  [32] top-level scope
#
#     @ c:\Users\ibzja\.vscode\extensions\julialang.language-julia-1.170.2\scripts\notebook\notebook.jl:28

# %%
Makie.inline(true)

# %%
rods2DChemotaxis = ABM(2,
    agent = Dict(
            :vx=>Float64,
            :vy=>Float64,
            :theta=>Float64,
            :ω=>Float64,
            :d=>Float64,
            :l=>Float64,
            :m=>Float64,
            :fx=>Float64,
            :fy=>Float64,
            :W=>Float64,
            :pressure=>Float64,
            :tTumble=>Float64, #We add to the agent a time to tumble or to run
            :active=>Bool,     #Add a switch to change between tumbling and running
        ),

    model = Dict(
            :kn=>Float64,
            :γn=>Float64,
            :γt=>Float64,
            :μcc=>Float64,
            :μcw=>Float64,
            :β=>Float64,
            :βω=>Float64,
            :ωTumble=>Float64, #Add a torque of tumbling
            :τTumble=>Float64, #Add a frequency of tumbling
            :fChem=>Float64,   #Add a force of propulsion
            :DMedium=>Float64, #Add a diffusion constant of the medium
            :ωMedium=>Float64  #Add a frequency of the oscillating medium
        ),

    medium = Dict(
        :mm => Float64        #Add a medium parameter
    ),

    agentODE = quote

        fx = 0
        fy = 0
        W = 0
        pressure = 0
        @loopOverNeighbors i2 begin

            Fijx, Fijy, Wij = CBMModels.rodForces(
                                    x,y,d,l,theta,vx,vy,m,
                                    x[i2],y[i2],d[i2],l[i2],theta[i2],vx[i2],vy[i2],m[i2],
                                    kn,γn,γt,μcc,μcw
                                )

            #Append the interaction forces
            fx += Fijx
            fy += Fijy
            #Append radial forces
            W += Wij
            #Keep track of preassure in the media
            pressure += sqrt(Fijx^2+Fijy^2)
            
        end

        #Equations
        dt(x) =  vx 
        dt(y) =  vy 
        dt(vx) =  -β*vx+fx/m + active * fChem * cos(theta) #Add the propulsion force
        dt(vy) =  -β*vy+fy/m + active * fChem * sin(theta) #Add the propulsion force
        dt(theta) =  ω
        dt(ω) =  W/(m*(d+l)^2/12+m*d^2)-βω*ω 
        
    end,

    agentRule = quote
        #Code rule switch between tumbling and running
        if tTumble < t && active #Activate tumbling if the particle was active (running) and the tumbling time ended
            vx = 0
            vy = 0
            active = false
            ω += ωTumble
            tTumble += 1.
        elseif tTumble < t && !active # Activate tumbling if the particle was tumbling (active off) and the running time ended (we resuse the tTumble time)
            ω = 0
            active = true
            tTumble += CBMDistributions.exponential((2-mm)*τTumble)
        end

        # Very rudementary rule to to fix the bacteries to move inside the boundaries using onluy the center of the rod
        if x < simBox[1,1]
            x = simBox[1,1]
        elseif x > simBox[1,2]
            x = simBox[1,2]
        end
        if y < simBox[2,1]
            y = simBox[2,1]
        elseif y > simBox[2,2]
            y = simBox[2,2]
        end

    end,

    #Medium dynamics with dirichlet conditions and a wall that is as oscillating source of material
    mediumODE=quote 
        if @mediumInside()
            dt(mm) = DMedium*@∂2(1,mm)# we only diffuse in x as the symmetry is in x
        elseif @mediumBorder(1,-1)
            mm = 0
        elseif @mediumBorder(1,1)
            mm = sin(ωMedium*t)+1 #Oscillatory behaviour
        elseif @mediumBorder(2,-1)
            mm = 0
        elseif @mediumBorder(2,-1)
            mm = 0
        end
    end,

    neighborsAlg=CBMNeighbors.CellLinked(cellEdge=4)
);

# %%
com = Community(
    rods2DChemotaxis,
    N=75,
    dt=0.1,
    simBox=[-20 20;-20 20.],
    NMedium=[200,200],
)

m = 1/100
g = 1/10000
d = 1
com.kn = 2E6      * (m*g/d)
com.γn = 2.2E2    * sqrt(g/d)
com.γt = 2.2E2    * sqrt(g/d)
com.μcc = 0.1
com.μcw = 0.8
com.β = .8
com.βω = .8
com.fChem = 1
com.τTumble = 2
# com.τTumbleMin = 1
com.ωTumble = 1
com.ωMedium = .01
com.DMedium = 3

com.m = 1.        
com.d = 1.        
com.l = 3;
com.x = rand(Uniform(com.simBox[1,:]...),com.N)
com.y = rand(Uniform(com.simBox[2,:]...),com.N)
com.theta = rand(Uniform(0,2π),com.N);

# %%
evolve!(com, steps = 5000, saveEach = 10)

# %%
function plotRods2D!(ax, x, y, d, l, angle; kargs...)

    Main.meshscatter!(ax,
                x.+l./2 .*cos.(angle),
                y.+l./2 .*sin.(angle),
                marker=Sphere(Point3f(0,0,0.),Float32(1)),
                markersize=[
                    Point3f0(i/2,i/2,0)
                    for i in d
                ],
                kargs...
            )

    Main.meshscatter!(ax,
                x.-l./2 .*cos.(angle),
                y.-l./2 .*sin.(angle),
                marker=Sphere(Point3f(0,0,0),Float32(1)),
                markersize=[
                    Point3f(i/2,i/2,0)
                    for i in d
                ],
                kargs...
            )
            
    Main.meshscatter!(ax,
                x,
                y,
                marker=Cylinder(Point3f(-.5,0,0),Point3f(.5,0,0),Float32(1)),
                markersize=[Point3f(ll,dd/2,dd/2) for (ll,dd) in zip(l,d)],
                rotation=angle,
                kargs...
            )

    return

end

function plotRods2D!(ax, x, y, xs1, ys1, xs2, ys2, markerSphere, markerCylinder, angle; kargs...)

    m = meshscatter!(ax,
                xs1,
                ys1,
                marker=Sphere(Point3f(0,0,0.),Float32(1)),
                markersize=markerSphere;
                kargs...
            )

    Main.meshscatter!(ax,
                xs2,
                ys2,
                marker=Sphere(Point3f(0,0,0),Float32(1)),
                markersize=markerSphere;
                kargs...
            )
            
    Main.meshscatter!(ax,
                x,
                y,
                marker=Cylinder(Point3f(-.5,0,0),Point3f(.5,0,0),Float32(1)),
                markersize=markerCylinder,
                rotation=angle;
                kargs...
            )

    return m

end

# %%
fig = Figure(size=(1800,400))

for (j,i) in enumerate(1:round(Int,length(com)/4):length(com))
    begin
        d = getParameter(com,[:x,:y,:d,:l,:theta,:pressure,:mm])

        ax = Axis(fig[1,2*j-1])

        m = heatmap!(ax,
                range(com.simBox[1,1],com.simBox[1,2],length=size(com.mm)[1]),
                range(com.simBox[2,1],com.simBox[2,2],length=size(com.mm)[1]),
                d[:mm][i],
                colorrange=(0,2.)
            )

        xlims!(com.simBox[1,:]...)
        ylims!(com.simBox[2,:]...)

        x = Observable(d[:x][i])
        y = Observable(d[:y][i])
        xs1 = Observable(d[:x][i]+d[:l][i]./2 .*cos.(d[:theta][i]))
        ys1 = Observable(d[:y][i]+d[:l][i]./2 .*sin.(d[:theta][i]))
        xs2 = Observable(d[:x][i]-d[:l][i]./2 .*cos.(d[:theta][i]))
        ys2 = Observable(d[:y][i]-d[:l][i]./2 .*sin.(d[:theta][i]))
        ms = Observable([Point3f(i/2,i/2,0) for i in d[:d][i]])
        mc = Observable([Point3f(ll,dd/2,dd/2) for (ll,dd) in zip(d[:l][i],d[:d][i])])
        theta = Observable(d[:theta][i])

        plotRods2D!(ax,x,y,xs1,ys1,xs2,ys2,ms,mc,theta,color=:red)

        Colorbar(fig[1,2*j],m)
    end
end

display(fig)

# %%
d = getParameter(com,[:x])

fig = Figure(size=(400,400))
ax = Axis(fig[1,1],xlabel="time",ylabel="medium",
            rightspinevisible=false,
            topspinevisible=false,
            xgridvisible=false,
            ygridvisible=false
        )

lines!(ax,[i.t for i in com.pastTimes],[1-cos(com.ωMedium[1]*i.t) for i in com.pastTimes])

ax2 = Axis(fig[2,1],xlabel="time",ylabel="mean(x)",
            rightspinevisible=false,
            topspinevisible=false,
            xgridvisible=false,
            ygridvisible=false
        )
lines!(ax2,[i.t for i in com.pastTimes],[mean(i) for i in d[:x]])

display(fig)
